# %%
import sklearn
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # PCA

# %%
def load_shopping_data(directory, features=None, label_name=['TripType']):
    data = pd.read_csv(directory)
    label = data[label_name].values.ravel()
    if features is None:
        content = data.drop(label_name, axis=1)
    else:
        content = data[features].values
    return content, label

# %%
pca = PCA(n_components=2)

# %%
directory = "GroupedData/train.csv"
# directory = "GroupedData/train_random.csv"
features = None

#directory = "MajorityVote/group_train.csv"
#directory = "MajorityVote/train_numerical.csv"
#features = ["VisitNumber","Weekday","ScanCount","DepartmentDescription"]

training_data, train_label = load_shopping_data(directory, features)

# %%
X = pca.fit(training_data).transform(training_data)

# %%
plt.figure()

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %% [markdown]
# # TSNE

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2)
X = tsne.fit_transform(training_data)

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.show()
